# %%
pip install spicy
# Out:
# Collecting spicy
#   Downloading spicy-0.16.0-py2.py3-none-any.whl.metadata (310 bytes)
# Requirement already satisfied: scipy in c:\users\risab\appdata\local\programs\python\python313\lib\site-packages (from spicy) (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\users\risab\appdata\local\programs\python\python313\lib\site-packages (from scipy->spicy) (2.3.5)
# Downloading spicy-0.16.0-py2.py3-none-any.whl (1.7 kB)
# Installing collected packages: spicy
# Successfully installed spicy-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Statistics

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# House prices dataset
house_prices = [150000, 180000, 200000, 220000, 240000, 1000000, 150000]

# Calculate measures of center
mean_price = np.mean(house_prices)
median_price = np.median(house_prices)
mode_price = stats.mode(house_prices, keepdims=True)

# Display results
print(f"Mean Price: ${mean_price:,.2f}")
print(f"Median Price: ${median_price:,.2f}")
print(f"Mode Price: ${mode_price.mode[0]:,.2f}, Count: {mode_price.count[0]}")
# Out:
# Mean Price: $305,714.29
# Median Price: $200,000.00
# Mode Price: $150,000.00, Count: 2
